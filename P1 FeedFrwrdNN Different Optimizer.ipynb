# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import SGD, Adam, RMSprop

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

epochs = 10
batch_size = 32
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()
metrics = ['accuracy']
optimizers = [
    SGD(),
    Adam(),
    RMSprop()
]

for optimizer in optimizers:
    model = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(128, activation='relu'),
        Dense(10, activation='softmax')
    ])

    model.compile(optimizer=optimizer, loss=loss_fn, metrics=metrics)

    model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1)

    test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
    print(f'Test Accuracy with {type(optimizer).__name__} optimizer: {test_acc}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6539 - accuracy: 0.8377
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3380 - accuracy: 0.9063
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2911 - accuracy: 0.9181
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2611 - accuracy: 0.9260
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2383 - accuracy: 0.9336
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2196 - accuracy: 0.9387
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2037 - accuracy: 0.9430
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1904 - accuracy: 0.9463
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1786 - accuracy: 0.9499
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1682 - accuracy: 0.9531
# 313/313 - 1s - loss: 0.1640 - accuracy: 0.9535 - 818ms/epoch - 3ms/step
# Test Accuracy with SGD optimizer: 0.953499972820282
# Epoch 1/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2625 - accuracy: 0.9253
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1154 - accuracy: 0.9663
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0803 - accuracy: 0.9763
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0599 - accuracy: 0.9815
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0468 - accuracy: 0.9852
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0377 - accuracy: 0.9883
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0292 - accuracy: 0.9907
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0238 - accuracy: 0.9929
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0200 - accuracy: 0.9937
# Epoch 10/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0164 - accuracy: 0.9948
# 313/313 - 1s - loss: 0.0858 - accuracy: 0.9778 - 678ms/epoch - 2ms/step
# Test Accuracy with Adam optimizer: 0.9778000116348267
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2616 - accuracy: 0.9232
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1181 - accuracy: 0.9651
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0846 - accuracy: 0.9749
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0664 - accuracy: 0.9805
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0549 - accuracy: 0.9839
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0467 - accuracy: 0.9858
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0389 - accuracy: 0.9885
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0346 - accuracy: 0.9899
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0306 - accuracy: 0.9912
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0261 - accuracy: 0.9922
# 313/313 - 1s - loss: 0.1023 - accuracy: 0.9764 - 667ms/epoch - 2ms/step
# Test Accuracy with RMSprop optimizer: 0.9764000177383423
